# %%
#Import needed library.
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('FCPS.DATA.csv',delimiter=',',header='infer')

# %%
# Delete data with no driving
df = df[df['GPS_DISTANCE'] !=0]
# Date
df['WEEKDAY'] = pd.DatetimeIndex(df['DATE']).weekday
df['MONTH'] = pd.DatetimeIndex(df['DATE']).month
df['YEAR'] = pd.DatetimeIndex(df['DATE']).year
# Supplement missing data
df['CARGO_WEIGHT'] = df['CARGO_WEIGHT'].fillna((df['CARGO_WEIGHT'].mean()))

# %%
df['START_MILEAGE'] = df['START_MILEAGE'].replace(' ','')
df["START_MILEAGE"] = df['START_MILEAGE'].astype(float)

# %%
# Separate features and labels
X, y = df[['WEEKDAY','MONTH','YEAR','GPS_DISTANCE','START_MILEAGE','CARGO_WEIGHT','DRIVER_ID','DRIVER_YEAR_BORN','TRUCK_ID',
'TRUCK_YEAR_PRODUCTION','KW','TRUCK_WEIGHT','MAX_TRUCK_TOTALWEIGHT','START_PLACE_ID','END_PLACE_ID','QTY_DRIVERS'
]].values, df['USED_FUEL'].values

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
# Split data 70%-30% into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

print ('Training Set: %d rows\nTest Set: %d rows' % (X_train.shape[0], X_test.shape[0]))
# Out:
# Training Set: 1257 rows
# Test Set: 540 rows

# %%
from sklearn import linear_model

# Train the model
model = linear_model.LinearRegression().fit(X_train, y_train)
print (model, "\n")

# Evaluate the model using the test data
predictions = model.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Used Fuel by LinearRegression model')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# LinearRegression()
#
# MSE: 560.6711741693533
# RMSE: 23.678496028450652
# R2: 0.8520464466863146

# %%
import joblib

# Save the model as a pickle file
filename = 'FCPS_LinearRegression.pkl'
joblib.dump(model, filename)
# Out:
# ['FCPS_LinearRegression.pkl']

# %%
from sklearn import linear_model

# Train the model
model = linear_model.Ridge().fit(X_train, y_train)
print (model, "\n")

# Evaluate the model using the test data
predictions = model.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels ')
plt.title('Predicted Used Fuel by Ridge model')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# C:\Anaconda 15.06.2021\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=7.59293e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# Ridge()
#
# MSE: 560.6829507198901
# RMSE: 23.678744703211994
# R2: 0.8520433390136216

# %%
import joblib

# Save the model as a pickle file
filename = 'FCPS_Ridge.pkl'
joblib.dump(model, filename)
# Out:
# ['FCPS_Ridge.pkl']

# %%
from sklearn import linear_model

# Train the model
model = linear_model.ElasticNet().fit(X_train, y_train)
print (model, "\n")

# Evaluate the model using the test data
predictions = model.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Used Fuel by ElasticNet model')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# ElasticNet()
#
# MSE: 580.556084048832
# RMSE: 24.09473145832574
# R2: 0.8467990874327378

# %%
import joblib

# Save the model as a pickle file
filename = 'FCPS_ElasticNet.pkl'
joblib.dump(model, filename)
# Out:
# ['FCPS_ElasticNet.pkl']

# %%
from sklearn import linear_model

# Train the model
model = linear_model.Lars().fit(X_train, y_train)
print (model, "\n")

# Evaluate the model using the test data
predictions = model.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Used Fuel by Lars model')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# Lars()
#
# MSE: 563.3317140497002
# RMSE: 23.734610046295266
# R2: 0.8513443661314987

# %%
import joblib

# Save the model as a pickle file
filename = 'FCPS_Lars.pkl'
joblib.dump(model, filename)
# Out:
# ['FCPS_Lars.pkl']

# %%
from sklearn import linear_model

# Train the model
model = linear_model.Lasso().fit(X_train, y_train)
print (model, "\n")

# Evaluate the model using the test data
predictions = model.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)


# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Used Fuel by Lasso model')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# Lasso()
#
# MSE: 578.6444815692078
# RMSE: 24.055030275790713
# R2: 0.8473035335188108

# %%
import joblib

# Save the model as a pickle file
filename = 'FCPS_Lasso.pkl'
joblib.dump(model, filename)
# Out:
# ['FCPS_Lasso.pkl']

# %%
from sklearn import linear_model

# Train the model
model = linear_model.LassoLars().fit(X_train, y_train)
print (model, "\n")

# Evaluate the model using the test data
predictions = model.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Used Fuel by LassoLars')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# LassoLars()
#
# MSE: 2062.2417683938584
# RMSE: 45.41191218605376
# R2: 0.45580223938245845

# %%
import joblib

# Save the model as a pickle file
filename = 'FCPS_LassoLars.pkl'
joblib.dump(model, filename)
# Out:
# ['FCPS_LassoLars.pkl']

# %%
from sklearn import linear_model

# Train the model
model = linear_model.LassoLarsIC().fit(X_train, y_train)
print (model, "\n")

# Evaluate the model using the test data
predictions = model.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Used Fuel by LassoLarsIC model')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# LassoLarsIC()
#
# MSE: 567.8656702651773
# RMSE: 23.82993223375126
# R2: 0.8501479162985957

# %%
import joblib

# Save the model as a pickle file
filename = 'FCPS_LassoLarsIC.pkl'
joblib.dump(model, filename)
# Out:
# ['FCPS_LassoLarsIC.pkl']

# %%
from sklearn import linear_model

# Train the model
model = linear_model.OrthogonalMatchingPursuit().fit(X_train, y_train)
print (model, "\n")

# Evaluate the model using the test data
predictions = model.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Used Fuel by OrthogonalMatchingPursuit')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# OrthogonalMatchingPursuit()
#
# MSE: 716.0282751985117
# RMSE: 26.75870466219379
# R2: 0.8110498051810136

# %%
import joblib

# Save the model as a pickle file
filename = 'FCPS_OrthogonalMatchingPursuit.pkl'
joblib.dump(model, filename)
# Out:
# ['FCPS_OrthogonalMatchingPursuit.pkl']

# %%
from sklearn import linear_model

# Train the model
model = linear_model.OrthogonalMatchingPursuitCV().fit(X_train, y_train)
print (model, "\n")

# Evaluate the model using the test data
predictions = model.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Used Fuel by OrthogonalMatchingPursuitCV')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# OrthogonalMatchingPursuitCV()
#
# MSE: 605.1221363658016
# RMSE: 24.59923040190082
# R2: 0.8403164378894109

# %%
import joblib

# Save the model as a pickle file
filename = 'FCPS_OrthogonalMatchingPursuitCV.pkl'
joblib.dump(model, filename)
# Out:
# ['FCPS_OrthogonalMatchingPursuitCV.pkl']

# %%
from sklearn import linear_model

# Train the model
model = linear_model.ARDRegression().fit(X_train, y_train)
print (model, "\n")

# Evaluate the model using the test data
predictions = model.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Used Fuel by ARDRegression model')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# ARDRegression()
#
# MSE: 716.0538210646047
# RMSE: 26.759181995431113
# R2: 0.811043063971843

# %%
import joblib

# Save the model as a pickle file
filename = 'FCPS_ARDRegression.pkl'
joblib.dump(model, filename)
# Out:
# ['FCPS_ARDRegression.pkl']

# %%
from sklearn import linear_model

# Train the model
model = linear_model.BayesianRidge().fit(X_train, y_train)
print (model, "\n")

# Evaluate the model using the test data
predictions = model.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Used Fuel by BayesianRidge')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# BayesianRidge()
#
# MSE: 585.7580167680737
# RMSE: 24.20243824014584
# R2: 0.8454263676187563

# %%
import joblib

# Save the model as a pickle file
filename = 'FCPS_BayesianRidge.pkl'
joblib.dump(model, filename)
# Out:
# ['FCPS_BayesianRidge.pkl']

# %%
from sklearn import linear_model

# Train the model
model = linear_model.RANSACRegressor().fit(X_train, y_train)
print (model, "\n")

# Evaluate the model using the test data
predictions = model.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Used Fuel by RANSACRegressor')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# RANSACRegressor()
#
# MSE: 704.7172615059919
# RMSE: 26.546511286909094
# R2: 0.8140346289859244

# %%
import joblib

# Save the model as a pickle file
filename = 'FCPS_RANSACRegressor.pkl'
joblib.dump(model, filename)
# Out:
# ['FCPS_RANSACRegressor.pkl']

# %%
from sklearn import linear_model

# Train the model
model = linear_model.TweedieRegressor().fit(X_train, y_train)
print (model, "\n")

# Evaluate the model using the test data
predictions = model.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, predictions)
print("R2:", r2)

# Plot predicted vs actual
plt.scatter(y_test, predictions)
plt.xlabel('Actual Labels')
plt.ylabel('Predicted Labels')
plt.title('Predicted Used Fuel by TweedieRegressor')
# overlay the regression line
z = np.polyfit(y_test, predictions, 1)
p = np.poly1d(z)
plt.plot(y_test,p(y_test), color='magenta')
plt.show()
# Out:
# C:\Anaconda 15.06.2021\lib\site-packages\sklearn\linear_model\_glm\glm.py:287: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# TweedieRegressor()
#
# MSE: 936.2123804940026
# RMSE: 30.597587821493423
# R2: 0.7529461924708967

# %%
import joblib

# Save the model as a pickle file
filename = 'FCPS_TweedieRegressor.pkl'
joblib.dump(model, filename)
# Out:
# ['FCPS_TweedieRegressor.pkl']
